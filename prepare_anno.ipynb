# %%
from google.colab import drive
from google.colab import files
import os

drive.mount('/content/drive')

os.chdir('/content/drive/MyDrive/VRDL/hw3')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/VRDL/hw3')
os.getcwd()
# Out:
# '/content/drive/MyDrive/VRDL/hw3'

# %%
# !pip install mmcv
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# !pip install pyyaml==5.1

# %%
# https://mmdetection.readthedocs.io/en/latest/2_new_data_model.html
# make custom dataset to coco cormat
import torch
import os.path as osp
import os
import mmcv
import json
from PIL import Image
import pycocotools._mask as _mask
import pycocotools.mask as mask_util
import numpy as np
from tqdm import tqdm
import re
import cv2
from detectron2.structures import polygons_to_bitmask

class RLE():
    def encode(self, bimask):
        bimask = np.asfortranarray(bimask)  
        if len(bimask.shape) == 3:
            return _mask.encode(bimask)
        elif len(bimask.shape) == 2:
            h, w = bimask.shape
            return _mask.encode(bimask.reshape((h, w, 1), order='F'))[0]
    def decode(self, rleObjs):
        if type(rleObjs) == list:
            return _mask.decode(rleObjs)
        else:
            return _mask.decode([rleObjs])[:,:,0]

    def area(self, rleObjs):
        if type(rleObjs) == list:
            return _mask.area(rleObjs)
        else:
            return _mask.area([rleObjs])[0]

    def toBbox(self, rleObjs):
        if type(rleObjs) == list:
            return _mask.toBbox(rleObjs)
        else:
            return _mask.toBbox([rleObjs])[0]
    def polygonFromMask(self, maskedArr): # https://github.com/hazirbas/coco-json-converter/blob/master/generate_coco_json.py

        contours, _ = cv2.findContours(maskedArr, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

        segmentation = []
        for contour in contours:
            # Valid polygons have >= 6 coordinates (3 points)
            if contour.size >= 6:
                segmentation.append(contour.flatten().tolist())
        RLEs = mask_util.frPyObjects(segmentation, maskedArr.shape[0], maskedArr.shape[1])
        RLE = mask_util.merge(RLEs)
        # RLE = mask.encode(np.asfortranarray(maskedArr))
        area = mask_util.area(RLE)
        [x, y, w, h] = cv2.boundingRect(maskedArr)

        return segmentation[0] #, [x, y, w, h], area

    def polygon_to_rle(self, polygon: list, shape=(1000, 1000)):
        '''
        polygon: a list of [x1, y1, x2, y2,....]
        shape: shape of bitmask
        Return: RLE type of mask
        '''
        mask = polygons_to_bitmask([np.asarray(polygon) + 0.25], shape[0], shape[1]) # add 0.25 can keep the pixels before and after the conversion unchanged
        rle = mask_util.encode(np.asfortranarray(mask))
        return rle

rle = RLE()

def convert_nuclei_to_coco(is_train=True):
    if is_train:
        mode = 'train'
    else:
        mode = 'test'

    images = []
    annotations = []
    anno_id = 0
    image_filename_list = os.listdir(osp.join('dataset', mode))
    image_filename_list = list(filter(lambda x: re.match('TCGA', x) != None, image_filename_list))
     
    for idx, filename in enumerate(image_filename_list):
        mask_filename_list = os.listdir(osp.join('dataset', mode, filename, 'masks'))
        mask_filename_list = list(filter(lambda x: re.match('.+\.png', x) != None, mask_filename_list))

        img_path = osp.join('dataset', mode, filename, 'images', filename + '.png')
        height, width = mmcv.imread(img_path).shape[:2]
        # For image
        images.append(dict(
            id = idx,
            file_name = filename+'.png',
            height = height,
            width = width))
        
        # For annotations
        for mask_name in tqdm(mask_filename_list):

            mask_path = osp.join('dataset', mode, filename, 'masks', mask_name)
            mask_img = mmcv.imread(mask_path, 0)
            poly = rle.polygonFromMask(mask_img)
            rle_code = rle.encode(mask_img)
            rle_code['counts'] = rle_code['counts'].decode('ascii')
            # just use first channel to encode
            # because the matrix are equal for each channels with each other
            rle_box = list(rle.toBbox(rle_code).tolist())# [x, y, width, height]
            rle_area = int(rle.area(rle_code))

            annotations.append(dict(
                    id = anno_id,
                    image_id = idx,
                    category_id = 1,
                    iscrowd = 0,
                    segmentation = [poly],
                    bbox = rle_box,
                    area = rle_area
                )
            )
            anno_id += 1

    categories=[{'id':1, 'name': 'cell', 'supercategory':'cell'}]
    coco_format_json = dict(
        images = images,
        annotations = annotations,
        categories=categories)
    return coco_format_json

coco_format_json = convert_nuclei_to_coco()

#save to json
with open('train_info.json', 'w') as f:
    json.dump(coco_format_json, f, indent=4)
# Out:
# 100%|██████████| 1073/1073 [00:10<00:00, 106.63it/s]
# 100%|██████████| 442/442 [00:04<00:00, 107.65it/s]
# 100%|██████████| 363/363 [00:03<00:00, 108.87it/s]
# 100%|██████████| 1165/1165 [00:10<00:00, 106.32it/s]
# 100%|██████████| 354/354 [00:03<00:00, 108.30it/s]
# 100%|██████████| 356/356 [00:03<00:00, 108.49it/s]
# 100%|██████████| 294/294 [00:02<00:00, 108.83it/s]
# 100%|██████████| 432/432 [00:03<00:00, 109.47it/s]
# 100%|██████████| 357/357 [00:03<00:00, 109.01it/s]
# 100%|██████████| 359/359 [00:03<00:00, 109.19it/s]
# 100%|██████████| 342/342 [00:03<00:00, 109.12it/s]
# 100%|██████████| 557/557 [00:05<00:00, 107.87it/s]
# 100%|██████████| 480/480 [00:04<00:00, 107.96it/s]
# 100%|██████████| 1584/1584 [00:14<00:00, 109.01it/s]
# 100%|██████████| 398/398 [00:03<00:00, 110.06it/s]
# 100%|██████████| 342/342 [00:03<00:00, 108.88it/s]
# 100%|██████████| 405/405 [00:03<00:00, 107.46it/s]
# 100%|██████████| 1862/1862 [00:17<00:00, 109.06it/s]
# 100%|██████████| 472/472 [00:04<00:00, 109.44it/s]
# 100%|██████████| 1391/1391 [00:12<00:00, 108.91it/s]
# 100%|██████████| 424/424 [00:03<00:00, 108.51it/s]
# 100%|██████████| 378/378 [00:03<00:00, 107.98it/s]
# 100%|██████████| 440/440 [00:04<00:00, 109.53it/s]
# 100%|██████████| 328/328 [00:03<00:00, 109.04it/s]

# %%
coco_format_json
# Out:
# {'annotations': [{'area': 147,
#    'bbox': [455.0, 208.0, 11.0, 17.0],
#    'category_id': 1,
#    'id': 0,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[459,
#      208,
#      458,
#      209,
#      457,
#      209,
#      456,
#      210,
#      456,
#      212,
#      455,
#      213,
#      455,
#      222,
#      457,
#      224,
#      459,
#      224,
#      460,
#      223,
#      461,
#      223,
#      463,
#      221,
#      463,
#      219,
#      465,
#      217,
#      465,
#      212,
#      464,
#      211,
#      464,
#      210,
#      463,
#      209,
#      462,
#      209,
#      461,
#      208]]},
#   {'area': 51,
#    'bbox': [374.0, 83.0, 9.0, 10.0],
#    'category_id': 1,
#    'id': 1,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[378,
#      83,
#      376,
#      85,
#      376,
#      86,
#      375,
#      87,
#      375,
#      88,
#      374,
#      89,
#      374,
#      92,
#      375,
#      92,
#      379,
#      88,
#      380,
#      88,
#      382,
#      86,
#      382,
#      84,
#      381,
#      83]]},
#   {'area': 116,
#    'bbox': [430.0, 787.0, 11.0, 13.0],
#    'category_id': 1,
#    'id': 2,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[435,
#      787,
#      434,
#      788,
#      431,
#      788,
#      430,
#      789,
#      430,
#      795,
#      431,
#      796,
#      431,
#      797,
#      433,
#      799,
#      437,
#      799,
#      437,
#      798,
#      439,
#      796,
#      439,
#      795,
#      440,
#      794,
#      440,
#      789,
#      439,
#      788,
#      438,
#      788,
#      437,
#      787]]},
#   {'area': 67,
#    'bbox': [766.0, 751.0, 10.0, 8.0],
#    'category_id': 1,
#    'id': 3,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[767,
#      751,
#      766,
#      752,
#      766,
#      756,
#      768,
#      758,
#      771,
#      758,
#      772,
#      757,
#      773,
#      757,
#      775,
#      755,
#      775,
#      752,
#      774,
#      752,
#      773,
#      751]]},
#   {'area': 46,
#    'bbox': [26.0, 846.0, 7.0, 8.0],
#    'category_id': 1,
#    'id': 4,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[27,
#      846,
#      26,
#      847,
#      26,
#      850,
#      27,
#      851,
#      27,
#      852,
#      29,
#      852,
#      30,
#      853,
#      31,
#      852,
#      32,
#      852,
#      32,
#      847,
#      31,
#      846]]},
#   {'area': 137,
#    'bbox': [494.0, 883.0, 13.0, 15.0],
#    'category_id': 1,
#    'id': 5,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[501,
#      883,
#      498,
#      886,
#      496,
#      886,
#      495,
#      887,
#      495,
#      889,
#      494,
#      890,
#      494,
#      891,
#      495,
#      892,
#      495,
#      895,
#      497,
#      897,
#      500,
#      897,
#      502,
#      895,
#      503,
#      895,
#      505,
#      893,
#      505,
#      892,
#      506,
#      891,
#      506,
#      889,
#      505,
#      888,
#      505,
#      884,
#      504,
#      884,
#      503,
#      883]]},
#   {'area': 78,
#    'bbox': [393.0, 238.0, 9.0, 12.0],
#    'category_id': 1,
#    'id': 6,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[394,
#      238,
#      393,
#      239,
#      393,
#      243,
#      394,
#      244,
#      394,
#      245,
#      398,
#      249,
#      400,
#      249,
#      400,
#      248,
#      401,
#      247,
#      401,
#      244,
#      400,
#      243,
#      400,
#      241,
#      399,
#      240,
#      399,
#      239,
#      398,
#      239,
#      397,
#      238]]},
#   {'area': 202,
#    'bbox': [305.0, 115.0, 16.0, 17.0],
#    'category_id': 1,
#    'id': 7,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[311,
#      115,
#      306,
#      120,
#      306,
#      121,
#      305,
#      122,
#      305,
#      125,
#      306,
#      126,
#      306,
#      127,
#      310,
#      131,
#      314,
#      131,
#      317,
#      128,
#      317,
#      127,
#      319,
#      125,
#      319,
#      123,
#      320,
#      122,
#      320,
#      118,
#      317,
#      115]]},
#   {'area': 50,
#    'bbox': [730.0, 693.0, 8.0, 8.0],
#    'category_id': 1,
#    'id': 8,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[732,
#      693,
#      731,
#      694,
#      730,
#      694,
#      730,
#      699,
#      731,
#      700,
#      734,
#      700,
#      735,
#      699,
#      736,
#      699,
#      736,
#      698,
#      737,
#      697,
#      737,
#      696,
#      736,
#      695,
#      736,
#      694,
#      734,
#      694,
#      733,
#      693]]},
#   {'area': 184,
#    'bbox': [175.0, 291.0, 16.0, 15.0],
#    'category_id': 1,
#    'id': 9,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[179,
#      291,
#      178,
#      292,
#      177,
#      292,
#      176,
#      293,
#      176,
#      294,
#      175,
#      295,
#      175,
#      297,
#      177,
#      299,
#      177,
#      300,
#      180,
#      303,
#      181,
#      303,
#      182,
#      304,
#      185,
#      304,
#      186,
#      305,
#      188,
#      305,
#      190,
#      303,
#      190,
#      296,
#      189,
#      295,
#      189,
#      294,
#      188,
#      293,
#      188,
#      292,
#      187,
#      292,
#      186,
#      291]]},
#   {'area': 67,
#    'bbox': [986.0, 603.0, 9.0, 10.0],
#    'category_id': 1,
#    'id': 10,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[989,
#      603,
#      986,
#      606,
#      986,
#      609,
#      987,
#      610,
#      988,
#      610,
#      989,
#      611,
#      990,
#      611,
#      991,
#      612,
#      994,
#      609,
#      994,
#      604,
#      993,
#      604,
#      992,
#      603]]},
#   {'area': 58,
#    'bbox': [407.0, 854.0, 8.0, 8.0],
#    'category_id': 1,
#    'id': 11,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[408,
#      854,
#      407,
#      855,
#      407,
#      860,
#      408,
#      861,
#      412,
#      861,
#      414,
#      859,
#      414,
#      855,
#      413,
#      854]]},
#   {'area': 57,
#    'bbox': [443.0, 976.0, 10.0, 8.0],
#    'category_id': 1,
#    'id': 12,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[444,
#      976,
#      443,
#      977,
#      443,
#      979,
#      446,
#      982,
#      447,
#      982,
#      448,
#      983,
#      451,
#      983,
#      451,
#      982,
#      452,
#      981,
#      451,
#      980,
#      451,
#      979,
#      450,
#      978,
#      450,
#      977,
#      449,
#      976]]},
#   {'area': 22,
#    'bbox': [372.0, 994.0, 7.0, 4.0],
#    'category_id': 1,
#    'id': 13,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[376,
#      994,
#      375,
#      995,
#      373,
#      995,
#      372,
#      996,
#      372,
#      997,
#      378,
#      997,
#      378,
#      995,
#      377,
#      994]]},
#   {'area': 103,
#    'bbox': [859.0, 324.0, 10.0, 13.0],
#    'category_id': 1,
#    'id': 14,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[861,
#      324,
#      859,
#      326,
#      859,
#      330,
#      860,
#      331,
#      860,
#      334,
#      862,
#      336,
#      868,
#      336,
#      868,
#      329,
#      863,
#      324]]},
#   {'area': 80,
#    'bbox': [127.0, 252.0, 10.0, 12.0],
#    'category_id': 1,
#    'id': 15,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[131,
#      252,
#      130,
#      253,
#      129,
#      253,
#      128,
#      254,
#      128,
#      255,
#      127,
#      256,
#      127,
#      259,
#      128,
#      260,
#      128,
#      262,
#      129,
#      262,
#      130,
#      263,
#      131,
#      262,
#      133,
#      262,
#      135,
#      260,
#      135,
#      259,
#      136,
#      258,
#      136,
#      257,
#      134,
#      255,
#      134,
#      254,
#      133,
#      253,
#      132,
#      253]]},
#   {'area': 142,
#    'bbox': [532.0, 606.0, 10.0, 17.0],
#    'category_id': 1,
#    'id': 16,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[536,
#      606,
#      533,
#      609,
#      533,
#      611,
#      532,
#      612,
#      532,
#      617,
#      533,
#      618,
#      533,
#      620,
#      535,
#      622,
#      539,
#      622,
#      540,
#      621,
#      540,
#      620,
#      541,
#      619,
#      541,
#      609,
#      540,
#      608,
#      540,
#      607,
#      539,
#      606]]},
#   {'area': 225,
#    'bbox': [466.0, 49.0, 15.0, 19.0],
#    'category_id': 1,
#    'id': 17,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[472,
#      49,
#      471,
#      50,
#      470,
#      50,
#      467,
#      53,
#      467,
#      55,
#      466,
#      56,
#      466,
#      61,
#      467,
#      62,
#      467,
#      64,
#      470,
#      67,
#      474,
#      67,
#      476,
#      65,
#      477,
#      65,
#      478,
#      64,
#      478,
#      63,
#      480,
#      61,
#      480,
#      54,
#      479,
#      53,
#      479,
#      52,
#      476,
#      49]]},
#   {'area': 138,
#    'bbox': [398.0, 89.0, 24.0, 15.0],
#    'category_id': 1,
#    'id': 18,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[421,
#      89,
#      418,
#      92,
#      417,
#      92,
#      413,
#      96,
#      411,
#      96,
#      410,
#      97,
#      407,
#      97,
#      406,
#      98,
#      400,
#      98,
#      399,
#      97,
#      398,
#      97,
#      400,
#      99,
#      400,
#      100,
#      402,
#      102,
#      402,
#      103,
#      407,
#      103,
#      408,
#      102,
#      410,
#      102,
#      411,
#      101,
#      416,
#      101,
#      418,
#      99,
#      418,
#      98,
#      419,
#      97,
#      419,
#      95,
#      420,
#      94,
#      420,
#      91,
#      421,
#      90]]},
#   {'area': 62,
#    'bbox': [344.0, 828.0, 9.0, 9.0],
#    'category_id': 1,
#    'id': 19,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[346,
#      828,
#      345,
#      829,
#      344,
#      829,
#      344,
#      832,
#      346,
#      834,
#      346,
#      835,
#      347,
#      835,
#      348,
#      836,
#      350,
#      836,
#      351,
#      835,
#      351,
#      833,
#      352,
#      832,
#      352,
#      829,
#      350,
#      829,
#      349,
#      828]]},
#   {'area': 130,
#    'bbox': [569.0, 236.0, 13.0, 12.0],
#    'category_id': 1,
#    'id': 20,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[571,
#      236,
#      570,
#      237,
#      570,
#      238,
#      569,
#      239,
#      569,
#      242,
#      570,
#      243,
#      570,
#      244,
#      571,
#      245,
#      571,
#      246,
#      572,
#      246,
#      573,
#      247,
#      578,
#      247,
#      579,
#      246,
#      580,
#      246,
#      580,
#      245,
#      581,
#      244,
#      581,
#      239,
#      579,
#      237,
#      578,
#      237,
#      577,
#      236]]},
#   {'area': 84,
#    'bbox': [722.0, 431.0, 8.0, 15.0],
#    'category_id': 1,
#    'id': 21,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[725,
#      431,
#      723,
#      433,
#      723,
#      436,
#      722,
#      437,
#      722,
#      442,
#      723,
#      443,
#      723,
#      445,
#      724,
#      445,
#      725,
#      444,
#      725,
#      443,
#      727,
#      441,
#      727,
#      440,
#      728,
#      439,
#      728,
#      438,
#      729,
#      437,
#      729,
#      432,
#      728,
#      432,
#      727,
#      431]]},
#   {'area': 88,
#    'bbox': [35.0, 802.0, 11.0, 11.0],
#    'category_id': 1,
#    'id': 22,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[36,
#      802,
#      36,
#      803,
#      35,
#      804,
#      35,
#      806,
#      36,
#      807,
#      36,
#      808,
#      37,
#      809,
#      37,
#      810,
#      38,
#      810,
#      39,
#      811,
#      40,
#      811,
#      41,
#      812,
#      45,
#      812,
#      45,
#      808,
#      44,
#      807,
#      44,
#      806,
#      43,
#      805,
#      43,
#      804,
#      42,
#      803,
#      40,
#      803,
#      39,
#      802]]},
#   {'area': 151,
#    'bbox': [435.0, 233.0, 13.0, 16.0],
#    'category_id': 1,
#    'id': 23,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[438,
#      233,
#      435,
#      236,
#      435,
#      242,
#      436,
#      243,
#      436,
#      244,
#      439,
#      247,
#      440,
#      247,
#      441,
#      248,
#      442,
#      248,
#      443,
#      247,
#      444,
#      247,
#      446,
#      245,
#      446,
#      244,
#      447,
#      243,
#      447,
#      241,
#      446,
#      240,
#      446,
#      238,
#      444,
#      236,
#      444,
#      235,
#      443,
#      235,
#      441,
#      233]]},
#   {'area': 34,
#    'bbox': [869.0, 856.0, 6.0, 9.0],
#    'category_id': 1,
#    'id': 24,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[873,
#      856,
#      871,
#      858,
#      871,
#      859,
#      870,
#      860,
#      870,
#      861,
#      869,
#      862,
#      871,
#      864,
#      873,
#      864,
#      874,
#      863,
#      874,
#      859,
#      873,
#      858]]},
#   {'area': 99,
#    'bbox': [409.0, 259.0, 11.0, 14.0],
#    'category_id': 1,
#    'id': 25,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[414,
#      259,
#      411,
#      262,
#      411,
#      264,
#      410,
#      265,
#      410,
#      267,
#      409,
#      268,
#      409,
#      270,
#      411,
#      272,
#      413,
#      272,
#      419,
#      266,
#      419,
#      265,
#      418,
#      264,
#      418,
#      262,
#      417,
#      261,
#      417,
#      260,
#      416,
#      259]]},
#   {'area': 35,
#    'bbox': [972.0, 36.0, 9.0, 6.0],
#    'category_id': 1,
#    'id': 26,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[975,
#      36,
#      974,
#      37,
#      973,
#      37,
#      972,
#      38,
#      972,
#      39,
#      973,
#      40,
#      974,
#      40,
#      975,
#      41,
#      976,
#      40,
#      979,
#      40,
#      979,
#      39,
#      980,
#      38,
#      979,
#      37,
#      978,
#      37,
#      977,
#      36]]},
#   {'area': 135,
#    'bbox': [714.0, 856.0, 14.0, 14.0],
#    'category_id': 1,
#    'id': 27,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[717,
#      856,
#      715,
#      858,
#      715,
#      859,
#      714,
#      860,
#      714,
#      862,
#      715,
#      863,
#      717,
#      863,
#      718,
#      864,
#      718,
#      866,
#      719,
#      867,
#      719,
#      868,
#      720,
#      869,
#      723,
#      869,
#      724,
#      868,
#      725,
#      868,
#      725,
#      867,
#      726,
#      866,
#      726,
#      865,
#      727,
#      864,
#      727,
#      862,
#      726,
#      861,
#      726,
#      860,
#      725,
#      859,
#      725,
#      858,
#      724,
#      858,
#      722,
#      856]]},
#   {'area': 187,
#    'bbox': [634.0, 546.0, 17.0, 14.0],
#    'category_id': 1,
#    'id': 28,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[639,
#      546,
#      638,
#      547,
#      637,
#      547,
#      635,
#      549,
#      635,
#      550,
#      634,
#      551,
#      634,
#      556,
#      635,
#      557,
#      635,
#      558,
#      636,
#      559,
#      639,
#      559,
#      640,
#      558,
#      642,
#      558,
#      643,
#      557,
#      644,
#      557,
#      645,
#      556,
#      646,
#      556,
#      647,
#      555,
#      648,
#      555,
#      650,
#      553,
#      650,
#      548,
#      648,
#      546]]},
#   {'area': 80,
#    'bbox': [696.0, 221.0, 10.0, 10.0],
#    'category_id': 1,
#    'id': 29,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[699,
#      221,
#      696,
#      224,
#      696,
#      226,
#      697,
#      227,
#      697,
#      229,
#      698,
#      230,
#      703,
#      230,
#      704,
#      229,
#      705,
#      229,
#      705,
#      224,
#      703,
#      222,
#      702,
#      222,
#      701,
#      221]]},
#   {'area': 66,
#    'bbox': [36.0, 388.0, 9.0, 10.0],
#    'category_id': 1,
#    'id': 30,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[37,
#      388,
#      36,
#      389,
#      36,
#      391,
#      37,
#      392,
#      37,
#      394,
#      40,
#      397,
#      44,
#      397,
#      44,
#      392,
#      41,
#      389,
#      40,
#      389,
#      39,
#      388]]},
#   {'area': 153,
#    'bbox': [625.0, 181.0, 17.0, 12.0],
#    'category_id': 1,
#    'id': 31,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[625,
#      181,
#      625,
#      188,
#      626,
#      189,
#      626,
#      190,
#      628,
#      192,
#      633,
#      192,
#      635,
#      190,
#      636,
#      190,
#      638,
#      188,
#      639,
#      188,
#      641,
#      186,
#      641,
#      184,
#      640,
#      184,
#      639,
#      183,
#      638,
#      183,
#      637,
#      182,
#      631,
#      182,
#      630,
#      181]]},
#   {'area': 261,
#    'bbox': [875.0, 318.0, 18.0, 19.0],
#    'category_id': 1,
#    'id': 32,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[885,
#      318,
#      884,
#      319,
#      881,
#      319,
#      880,
#      320,
#      877,
#      320,
#      877,
#      321,
#      876,
#      322,
#      876,
#      324,
#      875,
#      325,
#      875,
#      327,
#      876,
#      328,
#      876,
#      330,
#      877,
#      331,
#      877,
#      332,
#      881,
#      336,
#      886,
#      336,
#      887,
#      335,
#      888,
#      335,
#      891,
#      332,
#      891,
#      331,
#      892,
#      330,
#      892,
#      326,
#      891,
#      325,
#      891,
#      323,
#      890,
#      322,
#      890,
#      320,
#      888,
#      318]]},
#   {'area': 171,
#    'bbox': [532.0, 630.0, 14.0, 16.0],
#    'category_id': 1,
#    'id': 33,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[535,
#      630,
#      533,
#      632,
#      533,
#      633,
#      532,
#      634,
#      532,
#      639,
#      538,
#      645,
#      540,
#      645,
#      544,
#      641,
#      544,
#      640,
#      545,
#      639,
#      545,
#      634,
#      544,
#      633,
#      544,
#      632,
#      543,
#      631,
#      541,
#      631,
#      540,
#      630]]},
#   {'area': 217,
#    'bbox': [30.0, 727.0, 16.0, 17.0],
#    'category_id': 1,
#    'id': 34,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[36,
#      727,
#      35,
#      728,
#      34,
#      728,
#      31,
#      731,
#      31,
#      734,
#      30,
#      735,
#      30,
#      739,
#      31,
#      740,
#      31,
#      741,
#      33,
#      743,
#      41,
#      743,
#      44,
#      740,
#      44,
#      739,
#      45,
#      738,
#      45,
#      734,
#      44,
#      733,
#      44,
#      731,
#      41,
#      728,
#      40,
#      728,
#      39,
#      727]]},
#   {'area': 161,
#    'bbox': [16.0, 170.0, 13.0, 16.0],
#    'category_id': 1,
#    'id': 35,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[22,
#      170,
#      21,
#      171,
#      19,
#      171,
#      18,
#      172,
#      18,
#      173,
#      17,
#      174,
#      17,
#      175,
#      16,
#      176,
#      16,
#      181,
#      17,
#      182,
#      17,
#      183,
#      19,
#      185,
#      23,
#      185,
#      24,
#      184,
#      25,
#      184,
#      28,
#      181,
#      28,
#      176,
#      27,
#      175,
#      27,
#      174,
#      26,
#      173,
#      26,
#      172,
#      25,
#      171,
#      24,
#      171,
#      23,
#      170]]},
#   {'area': 74,
#    'bbox': [800.0, 571.0, 10.0, 9.0],
#    'category_id': 1,
#    'id': 36,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[805,
#      571,
#      804,
#      572,
#      802,
#      572,
#      801,
#      573,
#      801,
#      574,
#      800,
#      575,
#      800,
#      577,
#      801,
#      578,
#      801,
#      579,
#      808,
#      579,
#      808,
#      578,
#      809,
#      577,
#      809,
#      573,
#      807,
#      571]]},
#   {'area': 183,
#    'bbox': [34.0, 180.0, 14.0, 16.0],
#    'category_id': 1,
#    'id': 37,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[36,
#      180,
#      35,
#      181,
#      35,
#      182,
#      34,
#      183,
#      34,
#      189,
#      35,
#      190,
#      35,
#      191,
#      37,
#      193,
#      38,
#      193,
#      39,
#      194,
#      40,
#      194,
#      41,
#      195,
#      42,
#      195,
#      43,
#      194,
#      44,
#      194,
#      45,
#      193,
#      45,
#      192,
#      46,
#      191,
#      46,
#      190,
#      47,
#      189,
#      47,
#      182,
#      46,
#      181,
#      45,
#      181,
#      44,
#      180]]},
#   {'area': 116,
#    'bbox': [138.0, 587.0, 11.0, 14.0],
#    'category_id': 1,
#    'id': 38,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[141,
#      587,
#      139,
#      589,
#      139,
#      590,
#      138,
#      591,
#      138,
#      594,
#      139,
#      595,
#      139,
#      596,
#      140,
#      597,
#      140,
#      598,
#      141,
#      599,
#      142,
#      599,
#      143,
#      600,
#      146,
#      600,
#      148,
#      598,
#      148,
#      593,
#      147,
#      592,
#      147,
#      591,
#      145,
#      589,
#      145,
#      588,
#      144,
#      587]]},
#   {'area': 34,
#    'bbox': [253.0, 733.0, 8.0, 7.0],
#    'category_id': 1,
#    'id': 39,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[256,
#      733,
#      254,
#      735,
#      254,
#      737,
#      253,
#      738,
#      253,
#      739,
#      254,
#      738,
#      256,
#      738,
#      257,
#      737,
#      258,
#      737,
#      259,
#      736,
#      260,
#      736,
#      260,
#      734,
#      259,
#      733]]},
#   {'area': 201,
#    'bbox': [595.0, 464.0, 16.0, 16.0],
#    'category_id': 1,
#    'id': 40,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[601,
#      464,
#      600,
#      465,
#      598,
#      465,
#      597,
#      466,
#      596,
#      466,
#      596,
#      467,
#      595,
#      468,
#      595,
#      476,
#      598,
#      479,
#      604,
#      479,
#      605,
#      478,
#      605,
#      476,
#      607,
#      474,
#      608,
#      474,
#      610,
#      472,
#      610,
#      468,
#      606,
#      464]]},
#   {'area': 196,
#    'bbox': [978.0, 785.0, 16.0, 15.0],
#    'category_id': 1,
#    'id': 41,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[981,
#      785,
#      978,
#      788,
#      978,
#      793,
#      979,
#      794,
#      979,
#      796,
#      980,
#      797,
#      981,
#      797,
#      982,
#      798,
#      983,
#      798,
#      984,
#      799,
#      989,
#      799,
#      992,
#      796,
#      992,
#      795,
#      993,
#      794,
#      993,
#      790,
#      992,
#      789,
#      992,
#      788,
#      990,
#      786,
#      989,
#      786,
#      988,
#      785]]},
#   {'area': 92,
#    'bbox': [419.0, 281.0, 11.0, 11.0],
#    'category_id': 1,
#    'id': 42,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[423,
#      281,
#      422,
#      282,
#      421,
#      282,
#      419,
#      284,
#      419,
#      289,
#      420,
#      290,
#      421,
#      290,
#      422,
#      291,
#      423,
#      291,
#      424,
#      290,
#      426,
#      290,
#      429,
#      287,
#      429,
#      284,
#      426,
#      281]]},
#   {'area': 65,
#    'bbox': [428.0, 636.0, 10.0, 9.0],
#    'category_id': 1,
#    'id': 43,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[431,
#      636,
#      430,
#      637,
#      429,
#      637,
#      428,
#      638,
#      428,
#      640,
#      429,
#      641,
#      429,
#      642,
#      430,
#      642,
#      431,
#      643,
#      432,
#      643,
#      433,
#      644,
#      434,
#      644,
#      435,
#      643,
#      436,
#      643,
#      437,
#      642,
#      437,
#      639,
#      435,
#      637,
#      434,
#      637,
#      433,
#      636]]},
#   {'area': 68,
#    'bbox': [893.0, 682.0, 9.0, 10.0],
#    'category_id': 1,
#    'id': 44,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[895,
#      682,
#      894,
#      683,
#      894,
#      684,
#      893,
#      685,
#      893,
#      691,
#      897,
#      691,
#      901,
#      687,
#      901,
#      686,
#      900,
#      685,
#      900,
#      684,
#      899,
#      683,
#      898,
#      683,
#      897,
#      682]]},
#   {'area': 84,
#    'bbox': [16.0, 107.0, 11.0, 10.0],
#    'category_id': 1,
#    'id': 45,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[19,
#      107,
#      16,
#      110,
#      16,
#      114,
#      17,
#      115,
#      18,
#      115,
#      19,
#      116,
#      21,
#      116,
#      22,
#      115,
#      23,
#      115,
#      26,
#      112,
#      26,
#      111,
#      25,
#      110,
#      25,
#      108,
#      24,
#      107]]},
#   {'area': 125,
#    'bbox': [119.0, 685.0, 13.0, 12.0],
#    'category_id': 1,
#    'id': 46,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[123,
#      685,
#      122,
#      686,
#      121,
#      686,
#      119,
#      688,
#      119,
#      693,
#      120,
#      694,
#      120,
#      695,
#      121,
#      696,
#      126,
#      696,
#      127,
#      695,
#      128,
#      695,
#      131,
#      692,
#      131,
#      690,
#      130,
#      689,
#      130,
#      687,
#      129,
#      686,
#      128,
#      686,
#      127,
#      685]]},
#   {'area': 232,
#    'bbox': [657.0, 974.0, 17.0, 18.0],
#    'category_id': 1,
#    'id': 47,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[663,
#      974,
#      662,
#      975,
#      661,
#      975,
#      658,
#      978,
#      658,
#      980,
#      657,
#      981,
#      657,
#      985,
#      658,
#      986,
#      658,
#      987,
#      661,
#      990,
#      662,
#      990,
#      663,
#      991,
#      666,
#      991,
#      667,
#      990,
#      668,
#      990,
#      669,
#      989,
#      670,
#      989,
#      671,
#      988,
#      671,
#      987,
#      672,
#      986,
#      672,
#      984,
#      673,
#      983,
#      673,
#      981,
#      672,
#      980,
#      672,
#      977,
#      671,
#      976,
#      670,
#      976,
#      669,
#      975,
#      667,
#      975,
#      666,
#      974]]},
#   {'area': 114,
#    'bbox': [38.0, 133.0, 14.0, 11.0],
#    'category_id': 1,
#    'id': 48,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[41,
#      133,
#      40,
#      134,
#      39,
#      134,
#      39,
#      135,
#      38,
#      136,
#      38,
#      137,
#      39,
#      138,
#      39,
#      139,
#      40,
#      140,
#      41,
#      140,
#      43,
#      142,
#      46,
#      142,
#      47,
#      143,
#      48,
#      142,
#      49,
#      142,
#      50,
#      141,
#      51,
#      141,
#      51,
#      136,
#      49,
#      134,
#      48,
#      134,
#      47,
#      133]]},
#   {'area': 121,
#    'bbox': [542.0, 461.0, 15.0, 11.0],
#    'category_id': 1,
#    'id': 49,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[547,
#      461,
#      546,
#      462,
#      545,
#      462,
#      543,
#      464,
#      543,
#      466,
#      542,
#      467,
#      542,
#      468,
#      543,
#      469,
#      543,
#      470,
#      545,
#      470,
#      546,
#      471,
#      548,
#      471,
#      549,
#      470,
#      551,
#      470,
#      552,
#      469,
#      553,
#      469,
#      555,
#      467,
#      555,
#      465,
#      556,
#      464,
#      556,
#      463,
#      555,
#      462,
#      554,
#      462,
#      553,
#      461]]},
#   {'area': 99,
#    'bbox': [207.0, 728.0, 13.0, 9.0],
#    'category_id': 1,
#    'id': 50,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[208,
#      728,
#      207,
#      729,
#      207,
#      734,
#      208,
#      734,
#      209,
#      735,
#      210,
#      735,
#      211,
#      736,
#      217,
#      736,
#      219,
#      734,
#      219,
#      730,
#      217,
#      730,
#      216,
#      729,
#      215,
#      729,
#      214,
#      728]]},
#   {'area': 185,
#    'bbox': [679.0, 950.0, 14.0, 18.0],
#    'category_id': 1,
#    'id': 51,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[682,
#      950,
#      679,
#      953,
#      679,
#      956,
#      680,
#      957,
#      680,
#      959,
#      681,
#      960,
#      681,
#      961,
#      682,
#      962,
#      682,
#      963,
#      683,
#      964,
#      683,
#      966,
#      684,
#      966,
#      685,
#      967,
#      686,
#      967,
#      687,
#      966,
#      688,
#      966,
#      691,
#      963,
#      691,
#      962,
#      692,
#      961,
#      692,
#      954,
#      691,
#      953,
#      691,
#      952,
#      690,
#      951,
#      684,
#      951,
#      683,
#      950]]},
#   {'area': 57,
#    'bbox': [359.0, 298.0, 9.0, 9.0],
#    'category_id': 1,
#    'id': 52,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[363,
#      298,
#      362,
#      299,
#      361,
#      299,
#      360,
#      300,
#      360,
#      301,
#      359,
#      302,
#      359,
#      304,
#      361,
#      306,
#      363,
#      306,
#      365,
#      304,
#      366,
#      304,
#      366,
#      303,
#      367,
#      302,
#      367,
#      300,
#      366,
#      299,
#      365,
#      299,
#      364,
#      298]]},
#   {'area': 104,
#    'bbox': [634.0, 672.0, 16.0, 10.0],
#    'category_id': 1,
#    'id': 53,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[645,
#      672,
#      644,
#      673,
#      643,
#      673,
#      642,
#      674,
#      640,
#      674,
#      639,
#      675,
#      638,
#      675,
#      637,
#      676,
#      636,
#      676,
#      635,
#      677,
#      634,
#      677,
#      634,
#      679,
#      635,
#      680,
#      636,
#      680,
#      637,
#      681,
#      644,
#      681,
#      645,
#      680,
#      645,
#      679,
#      649,
#      675,
#      649,
#      673,
#      648,
#      672]]},
#   {'area': 234,
#    'bbox': [566.0, 885.0, 17.0, 17.0],
#    'category_id': 1,
#    'id': 54,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[570,
#      885,
#      569,
#      886,
#      568,
#      886,
#      567,
#      887,
#      567,
#      888,
#      566,
#      889,
#      566,
#      895,
#      567,
#      896,
#      567,
#      897,
#      570,
#      900,
#      571,
#      900,
#      572,
#      901,
#      578,
#      901,
#      579,
#      900,
#      580,
#      900,
#      582,
#      898,
#      582,
#      892,
#      581,
#      891,
#      581,
#      890,
#      577,
#      886,
#      576,
#      886,
#      575,
#      885]]},
#   {'area': 58,
#    'bbox': [404.0, 64.0, 9.0, 9.0],
#    'category_id': 1,
#    'id': 55,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[407,
#      64,
#      406,
#      65,
#      405,
#      65,
#      404,
#      66,
#      404,
#      70,
#      405,
#      70,
#      406,
#      71,
#      407,
#      71,
#      408,
#      72,
#      412,
#      68,
#      412,
#      66,
#      410,
#      64]]},
#   {'area': 98,
#    'bbox': [323.0, 666.0, 11.0, 11.0],
#    'category_id': 1,
#    'id': 56,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[326,
#      666,
#      323,
#      669,
#      323,
#      674,
#      325,
#      676,
#      329,
#      676,
#      330,
#      675,
#      332,
#      675,
#      332,
#      674,
#      333,
#      673,
#      333,
#      670,
#      332,
#      669,
#      332,
#      668,
#      331,
#      667,
#      330,
#      667,
#      329,
#      666]]},
#   {'area': 70,
#    'bbox': [828.0, 989.0, 10.0, 9.0],
#    'category_id': 1,
#    'id': 57,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[831,
#      989,
#      830,
#      990,
#      829,
#      990,
#      828,
#      991,
#      828,
#      994,
#      831,
#      997,
#      834,
#      997,
#      837,
#      994,
#      837,
#      991,
#      836,
#      990,
#      835,
#      990,
#      834,
#      989]]},
#   {'area': 41,
#    'bbox': [530.0, 412.0, 9.0, 7.0],
#    'category_id': 1,
#    'id': 58,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[535,
#      412,
#      534,
#      413,
#      532,
#      413,
#      531,
#      414,
#      531,
#      415,
#      530,
#      416,
#      532,
#      418,
#      533,
#      418,
#      534,
#      417,
#      536,
#      417,
#      538,
#      415,
#      538,
#      413,
#      537,
#      413,
#      536,
#      412]]},
#   {'area': 84,
#    'bbox': [544.0, 362.0, 12.0, 10.0],
#    'category_id': 1,
#    'id': 59,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[548,
#      362,
#      547,
#      363,
#      546,
#      363,
#      545,
#      364,
#      545,
#      365,
#      544,
#      366,
#      545,
#      367,
#      545,
#      368,
#      546,
#      369,
#      546,
#      370,
#      547,
#      371,
#      553,
#      371,
#      554,
#      370,
#      554,
#      368,
#      555,
#      367,
#      555,
#      366,
#      553,
#      364,
#      552,
#      364,
#      551,
#      363,
#      549,
#      363]]},
#   {'area': 66,
#    'bbox': [414.0, 471.0, 10.0, 9.0],
#    'category_id': 1,
#    'id': 60,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[418,
#      471,
#      417,
#      472,
#      416,
#      472,
#      415,
#      473,
#      415,
#      474,
#      414,
#      475,
#      414,
#      476,
#      415,
#      477,
#      415,
#      479,
#      418,
#      479,
#      419,
#      478,
#      420,
#      478,
#      422,
#      476,
#      423,
#      476,
#      423,
#      472,
#      421,
#      472,
#      420,
#      471]]},
#   {'area': 60,
#    'bbox': [165.0, 916.0, 8.0, 9.0],
#    'category_id': 1,
#    'id': 61,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[168,
#      916,
#      167,
#      917,
#      166,
#      917,
#      165,
#      918,
#      165,
#      923,
#      166,
#      924,
#      170,
#      924,
#      172,
#      922,
#      172,
#      917,
#      169,
#      917]]},
#   {'area': 132,
#    'bbox': [354.0, 582.0, 13.0, 13.0],
#    'category_id': 1,
#    'id': 62,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[360,
#      582,
#      359,
#      583,
#      356,
#      583,
#      354,
#      585,
#      354,
#      590,
#      358,
#      594,
#      365,
#      594,
#      365,
#      591,
#      366,
#      590,
#      366,
#      587,
#      364,
#      585,
#      364,
#      584,
#      363,
#      584,
#      361,
#      582]]},
#   {'area': 77,
#    'bbox': [129.0, 708.0, 10.0, 9.0],
#    'category_id': 1,
#    'id': 63,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[132,
#      708,
#      131,
#      709,
#      130,
#      709,
#      129,
#      710,
#      129,
#      713,
#      130,
#      714,
#      130,
#      715,
#      131,
#      716,
#      137,
#      716,
#      138,
#      715,
#      138,
#      710,
#      137,
#      709,
#      136,
#      709,
#      135,
#      708]]},
#   {'area': 52,
#    'bbox': [935.0, 20.0, 8.0, 9.0],
#    'category_id': 1,
#    'id': 64,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[936,
#      20,
#      935,
#      21,
#      935,
#      23,
#      936,
#      24,
#      936,
#      26,
#      938,
#      28,
#      942,
#      28,
#      942,
#      25,
#      941,
#      24,
#      941,
#      23,
#      938,
#      20]]},
#   {'area': 53,
#    'bbox': [59.0, 177.0, 8.0, 8.0],
#    'category_id': 1,
#    'id': 65,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[62,
#      177,
#      61,
#      178,
#      60,
#      178,
#      59,
#      179,
#      59,
#      182,
#      60,
#      183,
#      61,
#      183,
#      62,
#      184,
#      64,
#      184,
#      65,
#      183,
#      66,
#      183,
#      66,
#      178,
#      65,
#      177]]},
#   {'area': 182,
#    'bbox': [575.0, 91.0, 14.0, 17.0],
#    'category_id': 1,
#    'id': 66,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[581,
#      91,
#      576,
#      96,
#      576,
#      98,
#      575,
#      99,
#      575,
#      102,
#      577,
#      104,
#      577,
#      105,
#      578,
#      106,
#      579,
#      106,
#      580,
#      107,
#      587,
#      107,
#      588,
#      106,
#      588,
#      97,
#      586,
#      95,
#      586,
#      94,
#      584,
#      92,
#      582,
#      92]]},
#   {'area': 42,
#    'bbox': [20.0, 805.0, 6.0, 9.0],
#    'category_id': 1,
#    'id': 67,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[21,
#      805,
#      20,
#      806,
#      20,
#      811,
#      22,
#      813,
#      23,
#      813,
#      24,
#      812,
#      25,
#      812,
#      25,
#      808,
#      22,
#      805]]},
#   {'area': 59,
#    'bbox': [340.0, 30.0, 9.0, 8.0],
#    'category_id': 1,
#    'id': 68,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[341,
#      30,
#      340,
#      31,
#      340,
#      36,
#      341,
#      37,
#      342,
#      37,
#      343,
#      36,
#      344,
#      37,
#      346,
#      37,
#      347,
#      36,
#      347,
#      35,
#      348,
#      34,
#      348,
#      33,
#      345,
#      30]]},
#   {'area': 72,
#    'bbox': [965.0, 873.0, 9.0, 10.0],
#    'category_id': 1,
#    'id': 69,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[969,
#      873,
#      968,
#      874,
#      967,
#      874,
#      965,
#      876,
#      965,
#      880,
#      967,
#      882,
#      970,
#      882,
#      972,
#      880,
#      972,
#      879,
#      973,
#      878,
#      973,
#      874,
#      972,
#      873]]},
#   {'area': 45,
#    'bbox': [804.0, 20.0, 8.0, 7.0],
#    'category_id': 1,
#    'id': 70,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[806,
#      20,
#      804,
#      22,
#      804,
#      24,
#      806,
#      26,
#      809,
#      26,
#      810,
#      25,
#      810,
#      24,
#      811,
#      23,
#      811,
#      21,
#      810,
#      20]]},
#   {'area': 63,
#    'bbox': [75.0, 983.0, 9.0, 10.0],
#    'category_id': 1,
#    'id': 71,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[76,
#      983,
#      76,
#      984,
#      75,
#      985,
#      75,
#      988,
#      76,
#      989,
#      76,
#      990,
#      78,
#      992,
#      79,
#      991,
#      80,
#      991,
#      82,
#      989,
#      82,
#      986,
#      83,
#      985,
#      82,
#      984,
#      81,
#      984,
#      80,
#      983]]},
#   {'area': 47,
#    'bbox': [41.0, 967.0, 8.0, 7.0],
#    'category_id': 1,
#    'id': 72,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[43,
#      967,
#      41,
#      969,
#      41,
#      971,
#      43,
#      973,
#      48,
#      973,
#      48,
#      969,
#      46,
#      967]]},
#   {'area': 73,
#    'bbox': [159.0, 979.0, 9.0, 11.0],
#    'category_id': 1,
#    'id': 73,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[163,
#      979,
#      160,
#      982,
#      160,
#      983,
#      159,
#      984,
#      159,
#      987,
#      161,
#      989,
#      162,
#      989,
#      163,
#      988,
#      165,
#      988,
#      167,
#      986,
#      167,
#      981,
#      166,
#      980,
#      165,
#      980,
#      164,
#      979]]},
#   {'area': 68,
#    'bbox': [827.0, 245.0, 7.0, 14.0],
#    'category_id': 1,
#    'id': 74,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[829,
#      245,
#      828,
#      246,
#      828,
#      254,
#      827,
#      255,
#      827,
#      257,
#      828,
#      258,
#      829,
#      257,
#      830,
#      257,
#      832,
#      255,
#      832,
#      254,
#      833,
#      253,
#      833,
#      248,
#      830,
#      245]]},
#   {'area': 30,
#    'bbox': [818.0, 882.0, 6.0, 8.0],
#    'category_id': 1,
#    'id': 75,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[820,
#      882,
#      818,
#      884,
#      818,
#      885,
#      819,
#      886,
#      819,
#      887,
#      820,
#      888,
#      820,
#      889,
#      823,
#      889,
#      823,
#      887,
#      822,
#      886,
#      822,
#      885,
#      821,
#      884,
#      821,
#      883]]},
#   {'area': 92,
#    'bbox': [749.0, 790.0, 10.0, 12.0],
#    'category_id': 1,
#    'id': 76,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[753,
#      790,
#      752,
#      791,
#      751,
#      791,
#      751,
#      792,
#      750,
#      793,
#      750,
#      794,
#      749,
#      795,
#      749,
#      799,
#      751,
#      801,
#      754,
#      801,
#      755,
#      800,
#      756,
#      800,
#      757,
#      799,
#      757,
#      798,
#      758,
#      797,
#      758,
#      793,
#      756,
#      791,
#      755,
#      791,
#      754,
#      790]]},
#   {'area': 65,
#    'bbox': [868.0, 828.0, 11.0, 8.0],
#    'category_id': 1,
#    'id': 77,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[871,
#      828,
#      868,
#      831,
#      868,
#      834,
#      869,
#      835,
#      873,
#      835,
#      874,
#      834,
#      877,
#      834,
#      878,
#      833,
#      877,
#      832,
#      877,
#      830,
#      876,
#      830,
#      874,
#      828]]},
#   {'area': 188,
#    'bbox': [651.0, 626.0, 18.0, 16.0],
#    'category_id': 1,
#    'id': 78,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[660,
#      626,
#      659,
#      627,
#      658,
#      627,
#      658,
#      628,
#      656,
#      630,
#      656,
#      631,
#      655,
#      632,
#      654,
#      632,
#      653,
#      633,
#      653,
#      634,
#      651,
#      636,
#      651,
#      638,
#      653,
#      640,
#      655,
#      640,
#      656,
#      641,
#      658,
#      641,
#      659,
#      640,
#      661,
#      640,
#      664,
#      637,
#      665,
#      637,
#      666,
#      636,
#      667,
#      636,
#      668,
#      635,
#      668,
#      632,
#      667,
#      631,
#      667,
#      630,
#      666,
#      629,
#      666,
#      628,
#      664,
#      626]]},
#   {'area': 96,
#    'bbox': [155.0, 657.0, 9.0, 16.0],
#    'category_id': 1,
#    'id': 79,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[160,
#      657,
#      158,
#      659,
#      158,
#      660,
#      156,
#      662,
#      156,
#      663,
#      155,
#      664,
#      155,
#      667,
#      156,
#      668,
#      156,
#      670,
#      158,
#      672,
#      159,
#      671,
#      160,
#      671,
#      161,
#      670,
#      161,
#      669,
#      162,
#      668,
#      162,
#      666,
#      163,
#      665,
#      163,
#      661,
#      162,
#      660,
#      162,
#      659,
#      161,
#      658,
#      161,
#      657]]},
#   {'area': 134,
#    'bbox': [987.0, 836.0, 13.0, 13.0],
#    'category_id': 1,
#    'id': 80,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[988,
#      836,
#      987,
#      837,
#      987,
#      844,
#      988,
#      845,
#      988,
#      846,
#      989,
#      847,
#      990,
#      847,
#      991,
#      848,
#      994,
#      848,
#      995,
#      847,
#      996,
#      847,
#      997,
#      846,
#      998,
#      846,
#      998,
#      845,
#      999,
#      844,
#      999,
#      843,
#      998,
#      842,
#      998,
#      841,
#      997,
#      840,
#      997,
#      838,
#      996,
#      837,
#      995,
#      837,
#      994,
#      836]]},
#   {'area': 60,
#    'bbox': [241.0, 731.0, 9.0, 8.0],
#    'category_id': 1,
#    'id': 81,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[243,
#      731,
#      241,
#      733,
#      242,
#      734,
#      242,
#      736,
#      244,
#      738,
#      249,
#      738,
#      249,
#      732,
#      248,
#      731]]},
#   {'area': 49,
#    'bbox': [169.0, 430.0, 9.0, 8.0],
#    'category_id': 1,
#    'id': 82,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[170,
#      430,
#      169,
#      431,
#      169,
#      434,
#      170,
#      435,
#      170,
#      436,
#      171,
#      436,
#      172,
#      437,
#      173,
#      437,
#      176,
#      434,
#      176,
#      433,
#      177,
#      432,
#      176,
#      432,
#      175,
#      431,
#      174,
#      431,
#      173,
#      430]]},
#   {'area': 163,
#    'bbox': [285.0, 679.0, 16.0, 14.0],
#    'category_id': 1,
#    'id': 83,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[287,
#      679,
#      285,
#      681,
#      285,
#      686,
#      288,
#      689,
#      289,
#      689,
#      290,
#      690,
#      291,
#      690,
#      292,
#      691,
#      294,
#      691,
#      295,
#      692,
#      298,
#      692,
#      300,
#      690,
#      300,
#      685,
#      297,
#      682,
#      296,
#      682,
#      295,
#      681,
#      294,
#      681,
#      293,
#      680,
#      292,
#      680,
#      291,
#      679]]},
#   {'area': 47,
#    'bbox': [717.0, 658.0, 9.0, 8.0],
#    'category_id': 1,
#    'id': 84,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[721,
#      658,
#      720,
#      659,
#      719,
#      659,
#      718,
#      660,
#      718,
#      661,
#      717,
#      662,
#      717,
#      663,
#      718,
#      664,
#      718,
#      665,
#      721,
#      665,
#      724,
#      662,
#      724,
#      661,
#      725,
#      660,
#      724,
#      659,
#      723,
#      659,
#      722,
#      658]]},
#   {'area': 99,
#    'bbox': [832.0, 145.0, 9.0, 16.0],
#    'category_id': 1,
#    'id': 85,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[835,
#      145,
#      833,
#      147,
#      833,
#      149,
#      832,
#      150,
#      832,
#      154,
#      833,
#      155,
#      833,
#      157,
#      834,
#      158,
#      834,
#      159,
#      835,
#      160,
#      836,
#      160,
#      839,
#      157,
#      839,
#      156,
#      840,
#      155,
#      840,
#      152,
#      839,
#      151,
#      839,
#      149,
#      837,
#      147,
#      837,
#      146,
#      836,
#      146]]},
#   {'area': 105,
#    'bbox': [187.0, 971.0, 11.0, 13.0],
#    'category_id': 1,
#    'id': 86,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[191,
#      971,
#      190,
#      972,
#      189,
#      972,
#      188,
#      973,
#      188,
#      974,
#      187,
#      975,
#      187,
#      978,
#      189,
#      980,
#      189,
#      981,
#      190,
#      982,
#      191,
#      982,
#      192,
#      983,
#      194,
#      983,
#      195,
#      982,
#      196,
#      982,
#      197,
#      981,
#      197,
#      976,
#      195,
#      974,
#      195,
#      973,
#      194,
#      972,
#      193,
#      972,
#      192,
#      971]]},
#   {'area': 116,
#    'bbox': [467.0, 228.0, 11.0, 14.0],
#    'category_id': 1,
#    'id': 87,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[473,
#      228,
#      472,
#      229,
#      470,
#      229,
#      467,
#      232,
#      467,
#      237,
#      470,
#      240,
#      471,
#      240,
#      472,
#      241,
#      473,
#      241,
#      474,
#      240,
#      475,
#      240,
#      475,
#      239,
#      476,
#      238,
#      476,
#      237,
#      477,
#      236,
#      477,
#      230,
#      476,
#      230,
#      474,
#      228]]},
#   {'area': 165,
#    'bbox': [794.0, 334.0, 14.0, 15.0],
#    'category_id': 1,
#    'id': 88,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[800,
#      334,
#      799,
#      335,
#      798,
#      335,
#      795,
#      338,
#      795,
#      340,
#      794,
#      341,
#      794,
#      342,
#      795,
#      343,
#      795,
#      345,
#      796,
#      346,
#      796,
#      347,
#      797,
#      347,
#      798,
#      348,
#      804,
#      348,
#      805,
#      347,
#      805,
#      346,
#      806,
#      345,
#      806,
#      344,
#      807,
#      343,
#      807,
#      337,
#      805,
#      335,
#      804,
#      335,
#      803,
#      334]]},
#   {'area': 54,
#    'bbox': [146.0, 338.0, 8.0, 9.0],
#    'category_id': 1,
#    'id': 89,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[147,
#      338,
#      146,
#      339,
#      146,
#      343,
#      148,
#      345,
#      150,
#      345,
#      151,
#      346,
#      152,
#      346,
#      153,
#      345,
#      153,
#      342,
#      152,
#      341,
#      152,
#      340,
#      151,
#      339,
#      150,
#      339,
#      149,
#      338]]},
#   {'area': 160,
#    'bbox': [487.0, 706.0, 13.0, 16.0],
#    'category_id': 1,
#    'id': 90,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[491,
#      706,
#      488,
#      709,
#      488,
#      711,
#      487,
#      712,
#      487,
#      716,
#      488,
#      717,
#      488,
#      718,
#      489,
#      719,
#      489,
#      720,
#      490,
#      721,
#      494,
#      721,
#      496,
#      719,
#      497,
#      719,
#      497,
#      718,
#      498,
#      717,
#      498,
#      716,
#      499,
#      715,
#      499,
#      711,
#      498,
#      710,
#      498,
#      709,
#      496,
#      707,
#      495,
#      707,
#      494,
#      706]]},
#   {'area': 86,
#    'bbox': [750.0, 92.0, 12.0, 9.0],
#    'category_id': 1,
#    'id': 91,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[752,
#      92,
#      750,
#      94,
#      750,
#      97,
#      751,
#      98,
#      751,
#      99,
#      752,
#      100,
#      757,
#      100,
#      758,
#      99,
#      759,
#      99,
#      759,
#      98,
#      760,
#      97,
#      760,
#      96,
#      761,
#      95,
#      761,
#      94,
#      760,
#      93,
#      758,
#      93,
#      757,
#      92]]},
#   {'area': 47,
#    'bbox': [705.0, 820.0, 8.0, 9.0],
#    'category_id': 1,
#    'id': 92,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[706,
#      820,
#      705,
#      821,
#      705,
#      824,
#      709,
#      828,
#      711,
#      828,
#      712,
#      827,
#      712,
#      826,
#      711,
#      825,
#      711,
#      823,
#      709,
#      821,
#      708,
#      821,
#      707,
#      820]]},
#   {'area': 71,
#    'bbox': [98.0, 800.0, 11.0, 8.0],
#    'category_id': 1,
#    'id': 93,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[101,
#      800,
#      100,
#      801,
#      99,
#      801,
#      99,
#      802,
#      98,
#      803,
#      98,
#      805,
#      100,
#      807,
#      106,
#      807,
#      108,
#      805,
#      108,
#      803,
#      105,
#      800]]},
#   {'area': 44,
#    'bbox': [115.0, 273.0, 7.0, 8.0],
#    'category_id': 1,
#    'id': 94,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[118,
#      273,
#      115,
#      276,
#      115,
#      280,
#      118,
#      280,
#      121,
#      277,
#      121,
#      273]]},
#   {'area': 152,
#    'bbox': [777.0, 374.0, 17.0, 13.0],
#    'category_id': 1,
#    'id': 95,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[787,
#      374,
#      785,
#      376,
#      783,
#      376,
#      782,
#      377,
#      781,
#      377,
#      780,
#      378,
#      779,
#      378,
#      779,
#      379,
#      778,
#      380,
#      778,
#      381,
#      777,
#      382,
#      777,
#      384,
#      778,
#      384,
#      779,
#      385,
#      780,
#      385,
#      781,
#      386,
#      786,
#      386,
#      787,
#      385,
#      792,
#      385,
#      792,
#      384,
#      793,
#      383,
#      793,
#      381,
#      792,
#      380,
#      792,
#      379,
#      791,
#      378,
#      791,
#      377,
#      789,
#      375,
#      788,
#      375]]},
#   {'area': 252,
#    'bbox': [977.0, 402.0, 20.0, 17.0],
#    'category_id': 1,
#    'id': 96,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[986,
#      402,
#      985,
#      403,
#      984,
#      403,
#      983,
#      404,
#      982,
#      404,
#      981,
#      405,
#      980,
#      405,
#      978,
#      407,
#      978,
#      408,
#      977,
#      409,
#      977,
#      411,
#      978,
#      412,
#      978,
#      414,
#      980,
#      416,
#      981,
#      416,
#      982,
#      417,
#      983,
#      417,
#      984,
#      418,
#      988,
#      418,
#      989,
#      417,
#      992,
#      417,
#      995,
#      414,
#      995,
#      413,
#      996,
#      412,
#      996,
#      410,
#      995,
#      409,
#      995,
#      407,
#      993,
#      405,
#      993,
#      404,
#      992,
#      403,
#      991,
#      403,
#      990,
#      402]]},
#   {'area': 110,
#    'bbox': [444.0, 198.0, 11.0, 13.0],
#    'category_id': 1,
#    'id': 97,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[449,
#      198,
#      448,
#      199,
#      446,
#      199,
#      445,
#      200,
#      445,
#      201,
#      444,
#      202,
#      444,
#      206,
#      445,
#      207,
#      445,
#      208,
#      446,
#      208,
#      448,
#      210,
#      451,
#      210,
#      451,
#      208,
#      452,
#      207,
#      453,
#      207,
#      453,
#      205,
#      454,
#      204,
#      454,
#      200,
#      452,
#      198]]},
#   {'area': 70,
#    'bbox': [818.0, 83.0, 7.0, 12.0],
#    'category_id': 1,
#    'id': 98,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[821,
#      83,
#      820,
#      84,
#      819,
#      84,
#      819,
#      85,
#      818,
#      86,
#      818,
#      92,
#      820,
#      94,
#      822,
#      94,
#      824,
#      92,
#      824,
#      85,
#      822,
#      83]]},
#   {'area': 193,
#    'bbox': [467.0, 700.0, 17.0, 14.0],
#    'category_id': 1,
#    'id': 99,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[469,
#      700,
#      467,
#      702,
#      467,
#      709,
#      470,
#      712,
#      472,
#      712,
#      473,
#      713,
#      478,
#      713,
#      479,
#      712,
#      480,
#      712,
#      481,
#      711,
#      481,
#      710,
#      482,
#      709,
#      482,
#      708,
#      483,
#      707,
#      483,
#      705,
#      479,
#      701,
#      478,
#      701,
#      477,
#      700]]},
#   {'area': 55,
#    'bbox': [306.0, 678.0, 8.0, 9.0],
#    'category_id': 1,
#    'id': 100,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[309,
#      678,
#      308,
#      679,
#      307,
#      679,
#      306,
#      680,
#      306,
#      682,
#      307,
#      683,
#      307,
#      684,
#      309,
#      686,
#      312,
#      686,
#      313,
#      685,
#      313,
#      681,
#      312,
#      680,
#      312,
#      679,
#      311,
#      679,
#      310,
#      678]]},
#   {'area': 162,
#    'bbox': [118.0, 471.0, 13.0, 16.0],
# ...
#      268,
#      150,
#      267,
#      150,
#      263,
#      149,
#      262,
#      149,
#      261,
#      148,
#      260,
#      147,
#      260,
#      145,
#      258]]},
#   {'area': 132,
#    'bbox': [775.0, 857.0, 13.0, 15.0],
#    'category_id': 1,
#    'id': 972,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[776,
#      857,
#      776,
#      858,
#      775,
#      859,
#      775,
#      863,
#      776,
#      864,
#      776,
#      865,
#      778,
#      867,
#      778,
#      868,
#      781,
#      871,
#      783,
#      871,
#      783,
#      870,
#      786,
#      867,
#      786,
#      866,
#      787,
#      865,
#      787,
#      862,
#      784,
#      859,
#      782,
#      859,
#      781,
#      858,
#      779,
#      858,
#      778,
#      857]]},
#   {'area': 74,
#    'bbox': [203.0, 395.0, 11.0, 8.0],
#    'category_id': 1,
#    'id': 973,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[204,
#      395,
#      203,
#      396,
#      203,
#      400,
#      204,
#      401,
#      205,
#      401,
#      206,
#      402,
#      212,
#      402,
#      213,
#      401,
#      213,
#      399,
#      212,
#      398,
#      212,
#      397,
#      211,
#      396,
#      210,
#      396,
#      209,
#      395]]},
#   {'area': 33,
#    'bbox': [331.0, 66.0, 5.0, 8.0],
#    'category_id': 1,
#    'id': 974,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[333,
#      66,
#      332,
#      67,
#      331,
#      67,
#      331,
#      71,
#      332,
#      72,
#      332,
#      73,
#      334,
#      73,
#      334,
#      72,
#      335,
#      71,
#      335,
#      67,
#      334,
#      66]]},
#   {'area': 82,
#    'bbox': [337.0, 515.0, 12.0, 9.0],
#    'category_id': 1,
#    'id': 975,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[342,
#      515,
#      341,
#      516,
#      340,
#      516,
#      337,
#      519,
#      337,
#      520,
#      338,
#      521,
#      338,
#      522,
#      339,
#      523,
#      347,
#      523,
#      348,
#      522,
#      348,
#      520,
#      347,
#      519,
#      347,
#      517,
#      346,
#      516,
#      344,
#      516,
#      343,
#      515]]},
#   {'area': 107,
#    'bbox': [985.0, 820.0, 10.0, 13.0],
#    'category_id': 1,
#    'id': 976,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[988,
#      820,
#      987,
#      821,
#      986,
#      821,
#      985,
#      822,
#      985,
#      826,
#      986,
#      827,
#      986,
#      831,
#      987,
#      832,
#      991,
#      832,
#      992,
#      831,
#      993,
#      831,
#      994,
#      830,
#      994,
#      823,
#      992,
#      821,
#      990,
#      821,
#      989,
#      820]]},
#   {'area': 170,
#    'bbox': [690.0, 932.0, 16.0, 13.0],
#    'category_id': 1,
#    'id': 977,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[693,
#      932,
#      692,
#      933,
#      691,
#      933,
#      690,
#      934,
#      690,
#      941,
#      691,
#      942,
#      694,
#      942,
#      695,
#      943,
#      697,
#      943,
#      698,
#      944,
#      699,
#      944,
#      700,
#      943,
#      701,
#      943,
#      702,
#      942,
#      703,
#      942,
#      705,
#      940,
#      705,
#      935,
#      703,
#      933,
#      702,
#      933,
#      701,
#      932]]},
#   {'area': 152,
#    'bbox': [29.0, 760.0, 14.0, 15.0],
#    'category_id': 1,
#    'id': 978,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[33,
#      760,
#      29,
#      764,
#      29,
#      771,
#      31,
#      773,
#      33,
#      773,
#      34,
#      774,
#      38,
#      774,
#      39,
#      773,
#      40,
#      773,
#      41,
#      772,
#      41,
#      771,
#      42,
#      770,
#      42,
#      769,
#      41,
#      768,
#      41,
#      767,
#      40,
#      766,
#      40,
#      765,
#      36,
#      761,
#      35,
#      761,
#      34,
#      760]]},
#   {'area': 61,
#    'bbox': [181.0, 358.0, 11.0, 7.0],
#    'category_id': 1,
#    'id': 979,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[184,
#      358,
#      183,
#      359,
#      182,
#      359,
#      181,
#      360,
#      181,
#      363,
#      182,
#      364,
#      188,
#      364,
#      191,
#      361,
#      191,
#      360,
#      190,
#      359,
#      188,
#      359,
#      187,
#      358]]},
#   {'area': 48,
#    'bbox': [68.0, 677.0, 7.0, 8.0],
#    'category_id': 1,
#    'id': 980,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[69,
#      677,
#      68,
#      678,
#      68,
#      682,
#      70,
#      684,
#      73,
#      684,
#      74,
#      683,
#      74,
#      679,
#      72,
#      677]]},
#   {'area': 121,
#    'bbox': [633.0, 81.0, 14.0, 11.0],
#    'category_id': 1,
#    'id': 981,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[635,
#      81,
#      633,
#      83,
#      633,
#      87,
#      635,
#      89,
#      637,
#      89,
#      638,
#      90,
#      640,
#      90,
#      641,
#      91,
#      644,
#      91,
#      645,
#      90,
#      646,
#      90,
#      646,
#      87,
#      645,
#      86,
#      645,
#      84,
#      642,
#      81]]},
#   {'area': 154,
#    'bbox': [215.0, 775.0, 16.0, 16.0],
#    'category_id': 1,
#    'id': 982,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[227,
#      775,
#      225,
#      777,
#      225,
#      778,
#      222,
#      781,
#      221,
#      781,
#      220,
#      782,
#      219,
#      782,
#      218,
#      783,
#      216,
#      783,
#      215,
#      784,
#      215,
#      789,
#      216,
#      789,
#      217,
#      790,
#      224,
#      790,
#      226,
#      788,
#      227,
#      788,
#      228,
#      787,
#      228,
#      785,
#      229,
#      784,
#      229,
#      781,
#      230,
#      780,
#      230,
#      778,
#      228,
#      776,
#      228,
#      775]]},
#   {'area': 64,
#    'bbox': [439.0, 316.0, 10.0, 10.0],
#    'category_id': 1,
#    'id': 983,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[439,
#      316,
#      439,
#      320,
#      440,
#      321,
#      441,
#      321,
#      443,
#      323,
#      444,
#      323,
#      446,
#      325,
#      448,
#      325,
#      448,
#      321,
#      443,
#      316]]},
#   {'area': 46,
#    'bbox': [4.0, 429.0, 6.0, 10.0],
#    'category_id': 1,
#    'id': 984,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[6,
#      429,
#      5,
#      430,
#      5,
#      431,
#      4,
#      432,
#      4,
#      436,
#      5,
#      437,
#      5,
#      438,
#      7,
#      438,
#      7,
#      437,
#      8,
#      436,
#      8,
#      435,
#      9,
#      434,
#      9,
#      431,
#      8,
#      430,
#      8,
#      429]]},
#   {'area': 110,
#    'bbox': [134.0, 231.0, 12.0, 11.0],
#    'category_id': 1,
#    'id': 985,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[137,
#      231,
#      134,
#      234,
#      134,
#      239,
#      136,
#      241,
#      137,
#      241,
#      138,
#      240,
#      140,
#      240,
#      141,
#      241,
#      142,
#      241,
#      143,
#      240,
#      145,
#      240,
#      145,
#      235,
#      144,
#      234,
#      144,
#      233,
#      142,
#      231]]},
#   {'area': 132,
#    'bbox': [609.0, 121.0, 12.0, 14.0],
#    'category_id': 1,
#    'id': 986,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[611,
#      121,
#      610,
#      122,
#      609,
#      122,
#      609,
#      128,
#      610,
#      129,
#      610,
#      130,
#      613,
#      133,
#      615,
#      133,
#      616,
#      134,
#      617,
#      133,
#      618,
#      133,
#      619,
#      132,
#      619,
#      131,
#      620,
#      130,
#      620,
#      125,
#      619,
#      124,
#      619,
#      123,
#      618,
#      122,
#      617,
#      122,
#      616,
#      121]]},
#   {'area': 96,
#    'bbox': [719.0, 519.0, 12.0, 10.0],
#    'category_id': 1,
#    'id': 987,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[721,
#      519,
#      720,
#      520,
#      720,
#      521,
#      719,
#      522,
#      719,
#      524,
#      722,
#      527,
#      723,
#      527,
#      724,
#      528,
#      727,
#      528,
#      728,
#      527,
#      729,
#      527,
#      729,
#      526,
#      730,
#      525,
#      730,
#      521,
#      729,
#      520,
#      728,
#      520,
#      727,
#      519]]},
#   {'area': 104,
#    'bbox': [952.0, 764.0, 9.0, 14.0],
#    'category_id': 1,
#    'id': 988,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[956,
#      764,
#      954,
#      766,
#      954,
#      767,
#      953,
#      768,
#      953,
#      769,
#      952,
#      770,
#      952,
#      774,
#      953,
#      775,
#      953,
#      776,
#      954,
#      777,
#      958,
#      777,
#      960,
#      775,
#      960,
#      766,
#      959,
#      765,
#      959,
#      764]]},
#   {'area': 188,
#    'bbox': [448.0, 625.0, 15.0, 15.0],
#    'category_id': 1,
#    'id': 989,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[453,
#      625,
#      452,
#      626,
#      450,
#      626,
#      449,
#      627,
#      449,
#      628,
#      448,
#      629,
#      448,
#      635,
#      450,
#      637,
#      452,
#      637,
#      453,
#      638,
#      454,
#      638,
#      455,
#      639,
#      459,
#      639,
#      461,
#      637,
#      461,
#      635,
#      462,
#      634,
#      462,
#      627,
#      461,
#      626,
#      459,
#      626,
#      458,
#      625]]},
#   {'area': 225,
#    'bbox': [276.0, 55.0, 17.0, 18.0],
#    'category_id': 1,
#    'id': 990,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[283,
#      55,
#      277,
#      61,
#      277,
#      65,
#      276,
#      66,
#      277,
#      67,
#      277,
#      69,
#      278,
#      70,
#      279,
#      70,
#      280,
#      71,
#      282,
#      71,
#      283,
#      72,
#      284,
#      72,
#      285,
#      71,
#      288,
#      71,
#      290,
#      69,
#      290,
#      68,
#      292,
#      66,
#      292,
#      60,
#      291,
#      59,
#      291,
#      58,
#      289,
#      56,
#      287,
#      56,
#      286,
#      55]]},
#   {'area': 73,
#    'bbox': [792.0, 77.0, 11.0, 9.0],
#    'category_id': 1,
#    'id': 991,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[796,
#      77,
#      795,
#      78,
#      794,
#      78,
#      793,
#      79,
#      793,
#      80,
#      792,
#      81,
#      792,
#      82,
#      793,
#      83,
#      794,
#      83,
#      796,
#      85,
#      800,
#      85,
#      801,
#      84,
#      801,
#      83,
#      802,
#      82,
#      802,
#      79,
#      801,
#      79,
#      800,
#      78,
#      799,
#      78,
#      798,
#      77]]},
#   {'area': 113,
#    'bbox': [575.0, 214.0, 12.0, 13.0],
#    'category_id': 1,
#    'id': 992,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[582,
#      214,
#      581,
#      215,
#      579,
#      215,
#      578,
#      216,
#      577,
#      216,
#      575,
#      218,
#      575,
#      221,
#      576,
#      222,
#      576,
#      224,
#      578,
#      226,
#      579,
#      226,
#      580,
#      225,
#      581,
#      225,
#      582,
#      224,
#      583,
#      224,
#      585,
#      222,
#      585,
#      220,
#      586,
#      219,
#      586,
#      215,
#      585,
#      214]]},
#   {'area': 186,
#    'bbox': [613.0, 506.0, 14.0, 18.0],
#    'category_id': 1,
#    'id': 993,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[617,
#      506,
#      615,
#      508,
#      615,
#      509,
#      614,
#      510,
#      614,
#      512,
#      613,
#      513,
#      613,
#      517,
#      614,
#      518,
#      614,
#      519,
#      615,
#      520,
#      615,
#      521,
#      616,
#      521,
#      618,
#      523,
#      620,
#      523,
#      622,
#      521,
#      622,
#      520,
#      625,
#      517,
#      625,
#      515,
#      626,
#      514,
#      626,
#      510,
#      622,
#      506]]},
#   {'area': 49,
#    'bbox': [728.0, 304.0, 8.0, 8.0],
#    'category_id': 1,
#    'id': 994,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[729,
#      304,
#      728,
#      305,
#      728,
#      308,
#      729,
#      309,
#      729,
#      310,
#      730,
#      310,
#      731,
#      311,
#      733,
#      311,
#      734,
#      310,
#      735,
#      310,
#      735,
#      307,
#      733,
#      305,
#      732,
#      305,
#      731,
#      304]]},
#   {'area': 136,
#    'bbox': [556.0, 86.0, 11.0, 16.0],
#    'category_id': 1,
#    'id': 995,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[559,
#      86,
#      558,
#      87,
#      558,
#      88,
#      557,
#      89,
#      557,
#      91,
#      556,
#      92,
#      556,
#      94,
#      557,
#      95,
#      557,
#      97,
#      558,
#      98,
#      558,
#      99,
#      559,
#      100,
#      560,
#      100,
#      561,
#      101,
#      563,
#      101,
#      563,
#      100,
#      565,
#      98,
#      565,
#      96,
#      566,
#      95,
#      566,
#      89,
#      565,
#      88,
#      565,
#      87,
#      564,
#      86]]},
#   {'area': 74,
#    'bbox': [473.0, 826.0, 9.0, 10.0],
#    'category_id': 1,
#    'id': 996,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[474,
#      826,
#      473,
#      827,
#      473,
#      832,
#      475,
#      834,
#      476,
#      834,
#      477,
#      835,
#      478,
#      835,
#      479,
#      834,
#      480,
#      834,
#      481,
#      833,
#      481,
#      828,
#      480,
#      827,
#      479,
#      827,
#      478,
#      826]]},
#   {'area': 108,
#    'bbox': [175.0, 664.0, 12.0, 11.0],
#    'category_id': 1,
#    'id': 997,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[178,
#      664,
#      175,
#      667,
#      175,
#      671,
#      176,
#      672,
#      176,
#      673,
#      178,
#      673,
#      179,
#      674,
#      184,
#      674,
#      185,
#      673,
#      185,
#      672,
#      186,
#      671,
#      186,
#      668,
#      185,
#      667,
#      185,
#      666,
#      184,
#      665,
#      183,
#      665,
#      182,
#      664]]},
#   {'area': 223,
#    'bbox': [302.0, 81.0, 15.0, 19.0],
#    'category_id': 1,
#    'id': 998,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[309,
#      81,
#      308,
#      82,
#      307,
#      82,
#      305,
#      84,
#      304,
#      84,
#      304,
#      85,
#      302,
#      87,
#      302,
#      95,
#      303,
#      96,
#      303,
#      97,
#      304,
#      98,
#      306,
#      98,
#      307,
#      99,
#      308,
#      99,
#      309,
#      98,
#      310,
#      98,
#      314,
#      94,
#      314,
#      93,
#      316,
#      91,
#      316,
#      82,
#      315,
#      81]]},
#   {'area': 74,
#    'bbox': [940.0, 538.0, 10.0, 11.0],
#    'category_id': 1,
#    'id': 999,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [[945,
#      538,
#      944,
#      539,
#      943,
#      539,
#      941,
#      541,
#      941,
#      542,
#      940,
#      543,
#      940,
#      545,
#      941,
#      546,
#      941,
#      547,
#      942,
#      547,
#      943,
#      548,
#      944,
#      547,
#      945,
#      547,
#      947,
#      545,
#      947,
#      544,
#      948,
#      543,
#      948,
#      542,
#      949,
#      541,
#      949,
#      538]]},
#   ...],
#  'categories': [{'id': 1, 'name': 'cell', 'supercategory': 'cell'}],
#  'images': [{'file_name': 'TCGA-HE-7128-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 0,
#    'width': 1000},
#   {'file_name': 'TCGA-G9-6356-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 1,
#    'width': 1000},
#   {'file_name': 'TCGA-NH-A8F7-01A-01-TS1.png',
#    'height': 1000,
#    'id': 2,
#    'width': 1000},
#   {'file_name': 'TCGA-RD-A8N9-01A-01-TS1.png',
#    'height': 1000,
#    'id': 3,
#    'width': 1000},
#   {'file_name': 'TCGA-G9-6363-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 4,
#    'width': 1000},
#   {'file_name': 'TCGA-A7-A13F-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 5,
#    'width': 1000},
#   {'file_name': 'TCGA-CH-5767-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 6,
#    'width': 1000},
#   {'file_name': 'TCGA-AR-A1AK-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 7,
#    'width': 1000},
#   {'file_name': 'TCGA-B0-5698-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 8,
#    'width': 1000},
#   {'file_name': 'TCGA-B0-5710-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 9,
#    'width': 1000},
#   {'file_name': 'TCGA-B0-5711-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 10,
#    'width': 1000},
#   {'file_name': 'TCGA-49-4488-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 11,
#    'width': 1000},
#   {'file_name': 'TCGA-18-5592-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 12,
#    'width': 1000},
#   {'file_name': 'TCGA-HE-7129-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 13,
#    'width': 1000},
#   {'file_name': 'TCGA-21-5784-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 14,
#    'width': 1000},
#   {'file_name': 'TCGA-DK-A2I6-01A-01-TS1.png',
#    'height': 1000,
#    'id': 15,
#    'width': 1000},
#   {'file_name': 'TCGA-AR-A1AS-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 16,
#    'width': 1000},
#   {'file_name': 'TCGA-HE-7130-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 17,
#    'width': 1000},
#   {'file_name': 'TCGA-G9-6362-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 18,
#    'width': 1000},
#   {'file_name': 'TCGA-KB-A93J-01A-01-TS1.png',
#    'height': 1000,
#    'id': 19,
#    'width': 1000},
#   {'file_name': 'TCGA-38-6178-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 20,
#    'width': 1000},
#   {'file_name': 'TCGA-E2-A14V-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 21,
#    'width': 1000},
#   {'file_name': 'TCGA-21-5786-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 22,
#    'width': 1000},
#   {'file_name': 'TCGA-E2-A1B5-01Z-00-DX1.png',
#    'height': 1000,
#    'id': 23,
#    'width': 1000}]}
